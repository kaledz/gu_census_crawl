# %% [markdown]
# # SET UP

# %%
# Import libraries
from pyspark.sql.functions import lower
import pyspark.sql.functions as F
import pyspark.sql.types as T

# %%
# %run "/Workspace/Shared/gu_census_crawl/common_crawl/Seb_Test/(Clone) wet_files_extraction"
