# %%
df = spark.read.table("census_bureau_capstone.bronze.raw_all_crawls")

df.toPandas
display(df)

# %%
# %sql
select * from census_bureau_capstone.bronze.raw_all_crawls

# %%
df = spark.sql("""
SELECT *
FROM census_bureau_capstone.bronze.raw_all_crawls""")
