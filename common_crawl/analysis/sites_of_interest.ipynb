# %% [markdown]
# # Sites of Interest Investigation

# %% [markdown]
# The US Census Bureau noted some websites they would expect to appear in the data.
# - Urban Institute
# - Pew
#
# This workbook is an investigation if these websites are present in the data. If not, understanding why they're not appearing.

# %% [markdown]
# ## 1.0 Set Up

# %%
# Import libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# Load data
df = spark.table("census_bureau_capstone.gold.census_repackaged_enriched")
df = df.toPandas() # Convert to pandas dataframe

display(df)

# %% [markdown]
# ## 2.0 Are websites present in the data ingested?

# %% [markdown]
# ### 2.1 Urban Institute

# %% [markdown]
# Urban institute is not present in the data ingested.

# %%
# Check if Urban Institute is present in data
df[df['Target-URI'].str.contains('urbaninstitute.org')]

# %% [markdown]
# ### 2.2 Pew

# %% [markdown]
# Pew is present in the data ingested. However, all URI's are cited content - not repackaged.

# %%
# Check if Pew Research is present in data
display(df[df['Target-URI'].str.contains('pewresearch.org')])

# %% [markdown]
# ## 3.0 Investigate Specific URIs

# %% [markdown]
# ### 3.1 Urban Institute
